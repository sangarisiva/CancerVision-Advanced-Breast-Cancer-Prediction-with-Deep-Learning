# %%
# importing required libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Import the Libraries

# %% [markdown]
# # Load the Dataset
#
# ---

# %%
# load the dataset
df = pd.read_csv('/House Price India.csv')
df.head()

# %% [markdown]
# # Univariate Analysis
#
# ---

# %%
sns.distplot(df.lot_area_renov)
# Out:
# <ipython-input-6-fbd8f64c04a5>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.lot_area_renov)
# <Axes: xlabel='lot_area_renov', ylabel='Density'>

# %%
sns.distplot(df.Date)
# Out:
# <ipython-input-7-82d9cb3bf0f8>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Date)
# <Axes: xlabel='Date', ylabel='Density'>

# %%
sns.barplot(x=df.Lattitude.value_counts().index,y=df.Lattitude.value_counts())
# Out:
# <Axes: ylabel='Lattitude'>

# %% [markdown]
# # **Bivariate Analysis**
#
# ---

# %%
sns.lineplot(x=df.living_area_renov,y=df.lot_area_renov)
# Out:
# <Axes: xlabel='living_area_renov', ylabel='lot_area_renov'>

# %%
sns.scatterplot(x=df.Date,y=df.id)
# Out:
# <Axes: xlabel='Date', ylabel='id'>

# %% [markdown]
# # Multivariate Analysis
#
# ---

# %%
sns.pairplot(df)

# %% [markdown]
# # **Descriptive statistics**
#
# ---

# %%
# Display the descriptive statistics of the numerical variables in the dataframe
print(df.describe())
# Out:
#                  id          Date  number of bedrooms  number of bathrooms  \
# count  1.462000e+04  14620.000000        14620.000000         14620.000000
# mean   6.762821e+09  42604.538646            3.379343             2.129583
# std    6.237575e+03     67.347991            0.938719             0.769934
# min    6.762810e+09  42491.000000            1.000000             0.500000
# 25%    6.762815e+09  42546.000000            3.000000             1.750000
# 50%    6.762821e+09  42600.000000            3.000000             2.250000
# 75%    6.762826e+09  42662.000000            4.000000             2.500000
# max    6.762832e+09  42734.000000           33.000000             8.000000
#
#         living area      lot area  number of floors  waterfront present  \
# count  14620.000000  1.462000e+04      14620.000000        14620.000000
# mean    2098.262996  1.509328e+04          1.502360            0.007661
# std      928.275721  3.791962e+04          0.540239            0.087193
# ...

# %% [markdown]
# # Handle the Missing values
#
# ---

# %%
# Check the number of missing values in the "living_area" column
print("Number of missing values in the living_area column:", df["living_area_renov"].isnull().sum())

# Fill the missing values with the mean value
df["living_area_renov"].fillna(df["living_area_renov"].mean(), inplace=True)

# Verify that there are no more missing values in the "living_area" column
print("Number of missing values in the living_area_renov column after filling:", df["living_area_renov"].isnull().sum())
# Out:
# Number of missing values in the living_area column: 0
# Number of missing values in the living_area_renov column after filling: 0
